# %%
import op_art as xp
# Out:
# <style>
# .cell-rect {
#   stroke: #cdcdcd;
#   /* fill-opacity: 1; */
# }
# .cell-text {
#   font-family: Courier, sans-serif;
#   font-size: 14px;
#   text-anchor: middle;
#   dominant-baseline: central;
#   pointer-events: none;
# }
# .fixed-text {
#   font-family: Courier, sans-serif;
#   /* font-size: 20px; */
#   text-anchor: start;
#   dominant-baseline: hanging;
#   pointer-events: none;
#   white-space: pre;
# }
# .dimension-line {
#   stroke: black;
# }
# .reload {
#   font-family: Lucida Sans Unicode;
#   cursor: pointer;
# }
#
# </style>
# /Users/tom/projects-workspace/array-tracker/array_tracker/_array_object.py:7: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   import numpy.array_api as nxp

# %%
a = xp.arange(6)
a
# Out:
# Array(id=0,
# arr=[0 1 2 3 4 5],
# src_arr_ids=None,
# src_offsets=None)

# %%
b = xp.reshape(a, (3, 2))
b
# Out:
# Array(id=1,
# arr=[[0 1]
#  [2 3]
#  [4 5]],
# src_arr_ids=[[[0]
#   [0]]
#
#  [[0]
#   [0]]
#
#  [[0]
#   [0]]],
# src_offsets=[[[0]
#   [1]]
#
#  [[2]
#   [3]]
#
#  [[4]
#   [5]]])

# %%
a = xp.arange(6)
b = xp.reshape(a, (3, 2))
xp.visualize(a, b)
